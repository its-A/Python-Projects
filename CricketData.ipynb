# %%
#using data from https://www.espncricinfo.com/records/highest-career-batting-average-282910
#will be cleaning using python to clean data

# %%
#import pandas

# %%
import pandas as pd

# %%
#importing csv file

# %%
df = pd.read_csv('CricketData.csv')

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 61   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7  626+   6
# ...

# %%
#rename multiple columns

# %%
df = df.rename(columns = {'Mat':'Matches','NO':'Not_Outs','HS':'Highest_Inns_Score','BF':'Balls_Faced','SR':'Batting_Strike_Rate'})

# %%
df.head()
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1    AC Voges (AUS)  2015-2016       20    31         7  1485
# 2    AC Voges (AUS)  2015-2016       20    31         7  1485
# 3   RG Pollock (SA)  1963-1970       23    41         4  2256
# 4   GA Headley (WI)  1930-1954       22    40         4  2190
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 0                334  99.94       9800+                58.60   29  13  7
# 1               269*  61.87        2667                55.68    5   4  2
# 2               269*  61.87        2667                55.68    5   4  2
# 3                274  60.97       1707+                54.48    7  11  1
# 4               270*  60.83        416+                56.00   10   5  2
#
#      4s  6s
# 0  626+   6
# 1   186   5
# 2   186   5
# 3  246+  11
# 4  104+   1

# %%
#check for NULL values

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#                   Player       Span  Matches  Inns  Not_Outs  Runs  \
# 8         ED Weekes (WI)  1948-1958       48    81         5  4455
# 15       CL Walcott (WI)  1948-1960       44    74         7  3798
# 58  Hon.FS Jackson (ENG)  1893-1905       20    33         4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 8                 207  58.61         NaN                  0.0   15  19  6
# 15                220  56.68         NaN                  0.0   15  14  1
# 58               144*  48.79         NaN                  0.0    5   6  3
#
#       4s  6s
# 8   258+   2
# 15  107+  11
# 58   51+   0

# %%
#fill in null values (50/50 correct, but for this purpose its okay)

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
#battin strike also has nulls, so filling those in too

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].fillna(0)

# %%
df[df['Player'] == 'ED Weekes (WI)']
# Out:
#            Player       Span  Matches  Inns  Not_Outs  Runs  \
# 8  ED Weekes (WI)  1948-1958       48    81         5  4455
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 8                207  58.61           0                  0.0   15  19  6
#
#      4s 6s
# 8  258+  2

# %%
df[df['Player'] =='CL Walcott (WI)']
# Out:
#              Player       Span  Matches  Inns  Not_Outs  Runs  \
# 15  CL Walcott (WI)  1948-1960       44    74         7  3798
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 15                220  56.68           0                  0.0   15  14  1
#
#       4s  6s
# 15  107+  11

# %%
#drop duplicate values

# %%
df.duplicated() #will search for duplicates
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
#       ...
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# Length: 66, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#                Player       Span  Matches  Inns  Not_Outs   Runs  \
# 2      AC Voges (AUS)  2015-2016       20    31         7   1485
# 17     L Hutton (ENG)  1937-1955       79   138        15   6971
# 32  Younis Khan (PAK)  2000-2017      118   213        19  10099
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 2                269*  61.87        2667                55.68    5   4   2
# 17                364  56.67       2844+                39.34   19  33   5
# 32                313  52.05       19375                52.12   34  33  19
#
#       4s  6s
# 2    186   5
# 17  358+   7
# 32  1082  70

# %%
df = df.drop_duplicates()

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 3     False
# 4     False
# 5     False
#       ...
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# Length: 63, dtype: bool

# %%
#split up span to start & end date

# %%
df['Span']
# Out:
# 0     1928-1948
# 1     2015-2016
# 3     1963-1970
# 4     1930-1954
# 5     1924-1935
#         ...
# 61    1965-1981
# 62    2002-2014
# 63    1924-1934
# 64    1930-1938
# 65    1928-1934
# Name: Span, Length: 63, dtype: object

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
# 5     [1924, 1935]
#           ...
# 61    [1965, 1981]
# 62    [2002, 2014]
# 63    [1924, 1934]
# 64    [1930, 1938]
# 65    [1928, 1934]
# Name: Span, Length: 63, dtype: object

# %%
#how to assign rookie year [0] & final year[1]

# %%
df['Rookie_Year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['Final_Year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df #now shows new columns for rookie year & final year
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1      AC Voges (AUS)  2015-2016       20    31         7  1485
# 3     RG Pollock (SA)  1963-1970       23    41         4  2256
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# 5   H Sutcliffe (ENG)  1924-1935       54    84         9  4555
# ..                ...        ...      ...   ...       ...   ...
# 61   KD Walters (AUS)  1965-1981       74   125        14  5357
# 62  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 63  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 64    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 65   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# ...

# %%
#drop Span column

# %%
df = df.drop(['Span'], axis = 1)

# %%
df.head() #now shows my table with no span column
# Out:
#               Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0   DG Bradman (AUS)       52    80        10  6996                334  99.94
# 1     AC Voges (AUS)       20    31         7  1485               269*  61.87
# 3    RG Pollock (SA)       23    41         4  2256                274  60.97
# 4    GA Headley (WI)       22    40         4  2190               270*  60.83
# 5  H Sutcliffe (ENG)       54    84         9  4555                194  60.73
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7  626+   6        1928
# 1        2667                55.68    5   4  2   186   5        2015
# 3       1707+                54.48    7  11  1  246+  11        1963
# 4        416+                56.00   10   5  2  104+   1        1930
# 5       6558+                34.59   16  23  2  202+   6        1924
#
#   Final_Year
# 0       1948
# 1       2016
# 3       1970
# 4       1954
# ...

# %%
#split up country from player

# %%
df['Player'].str.split(pat = '(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
# 5     [H Sutcliffe , ENG)]
#               ...
# 61     [KD Walters , AUS)]
# 62    [GC Smith , ICC/SA)]
# 63    [WH Ponsford , AUS)]
# 64      [SJ McCabe , AUS)]
# 65     [DR Jardine , ENG)]
# Name: Player, Length: 63, dtype: object

# %%
df['Country'] = df['Player'].str.split(pat = '(').str[1]

# %%
df['Country']
# Out:
# 0        AUS)
# 1        AUS)
# 3         SA)
# 4         WI)
# 5        ENG)
#        ...
# 61       AUS)
# 62    ICC/SA)
# 63       AUS)
# 64       AUS)
# 65       ENG)
# Name: Country, Length: 63, dtype: object

# %%
df['Country'].str.split(pat = ')')
# Out:
# 0        [AUS, ]
# 1        [AUS, ]
# 3         [SA, ]
# 4         [WI, ]
# 5        [ENG, ]
#          ...
# 61       [AUS, ]
# 62    [ICC/SA, ]
# 63       [AUS, ]
# 64       [AUS, ]
# 65       [ENG, ]
# Name: Country, Length: 63, dtype: object

# %%
df['Country'] = df['Country'].str.split(pat = ')').str[0]

# %%
df['Country']
# Out:
# 0        AUS
# 1        AUS
# 3         SA
# 4         WI
# 5        ENG
#        ...
# 61       AUS
# 62    ICC/SA
# 63       AUS
# 64       AUS
# 65       ENG
# Name: Country, Length: 63, dtype: object

# %%
#gotta fix player & remove the country

# %%
df['Player'] = df['Player'].str.split(pat = '(').str[0]

# %%
df['Player']
# Out:
# 0      DG Bradman
# 1        AC Voges
# 3      RG Pollock
# 4      GA Headley
# 5     H Sutcliffe
#           ...
# 61     KD Walters
# 62       GC Smith
# 63    WH Ponsford
# 64      SJ McCabe
# 65     DR Jardine
# Name: Player, Length: 63, dtype: object

# %%
df.head()
# Out:
#          Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0   DG Bradman        52    80        10  6996                334  99.94
# 1     AC Voges        20    31         7  1485               269*  61.87
# 3   RG Pollock        23    41         4  2256                274  60.97
# 4   GA Headley        22    40         4  2190               270*  60.83
# 5  H Sutcliffe        54    84         9  4555                194  60.73
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7  626+   6        1928
# 1        2667                55.68    5   4  2   186   5        2015
# 3       1707+                54.48    7  11  1  246+  11        1963
# 4        416+                56.00   10   5  2  104+   1        1930
# 5       6558+                34.59   16  23  2  202+   6        1924
#
#   Final_Year Country
# 0       1948     AUS
# 1       2016     AUS
# 3       1970      SA
# ...

# %%
#change data types

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
#upon reviewing the data types the following need to be changed 
#Highest_Inns_Score -> INT
#Balls_Faced -> INT
#Batting_Strike_Rate -> INT
#Rookie_Year -> INT
#Final_Year -> INT

# %%
#changing Highest_Inns_Score from object to int (bc of the * in data it was classified as an object)

# %%
df['Highest_Inns_Score'].str.split(pat = '*').str[0]
# Out:
# 0     334
# 1     269
# 3     274
# 4     270
# 5     194
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: Highest_Inns_Score, Length: 63, dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].str.split(pat = '*').str[0]

# %%
df['Highest_Inns_Score'].astype('int')
# Out:
# 0     334
# 1     269
# 3     274
# 4     270
# 5     194
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: Highest_Inns_Score, Length: 63, dtype: int64

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
#shorter way of changing data types

# %%
df = df.astype({'Rookie_Year':'int','Final_Year':'int'})

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat = '+').str[0]

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#              Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 8        ED Weekes        48    81         5  4455                 207  58.61
# 15      CL Walcott        44    74         7  3798                 220  56.68
# 58  Hon.FS Jackson        20    33         4  1415                 144  48.79
#
#    Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s  Rookie_Year  \
# 8          NaN                  0.0   15  19  6  258+   2         1948
# 15         NaN                  0.0   15  14  1  107+  11         1948
# 58         NaN                  0.0    5   6  3   51+   0         1893
#
#     Final_Year Country
# 8         1958      WI
# 15        1960      WI
# 58        1905     ENG

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df['4s'] = df['4s'].str.split(pat = '+').str[0]

# %%
df['4s'] = df['4s'].astype('int')

# %%
df['6s'] = df['6s'].str.split(pat = '+').str[0]

# %%
df['6s'] = df['6s'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
#Find Career Length

# %%
df['Career Length'] = df['Final_Year'] - df['Rookie_Year']

# %%
df
# Out:
#           Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0    DG Bradman        52    80        10  6996                 334  99.94
# 1      AC Voges        20    31         7  1485                 269  61.87
# 3    RG Pollock        23    41         4  2256                 274  60.97
# 4    GA Headley        22    40         4  2190                 270  60.83
# 5   H Sutcliffe        54    84         9  4555                 194  60.73
# ..           ...      ...   ...       ...   ...                 ...    ...
# 61   KD Walters        74   125        14  5357                 250  48.26
# 62     GC Smith       117   205        13  9265                 277  48.25
# 63  WH Ponsford        29    48         4  2122                 266  48.22
# 64    SJ McCabe        39    62         5  2748                 232  48.21
# 65   DR Jardine        22    33         6  1296                 127  48.00
#
# ...

# %%
#Question1: Average Career Length

# %%
df['Career Length'].mean()
# Out:
# np.float64(13.031746031746032)

# %%
#Question2: Average Batting_Strike_Rate for players who have played over 10 yrs

# %%
df[df['Career Length'] > 10]['Batting_Strike_Rate'].mean()
# Out:
# np.float64(47.95727272727272)

# %%
#Question3: Find the number of players who played before 1960

# %%
df[df['Rookie_Year'] < 1960]['Player'].count()
# Out:
# np.int64(23)

# %%
#Question4: Max Highest Inns Score by Country

# %%
df.groupby('Country')['Highest_Inns_Score'].max()
# Out:
# Country
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# ICC/SA     277
# ICC/WI     400
# IND        254
# NZ         251
# PAK        313
# SA         278
# SL         374
# WI         365
# ZIM        232
# Name: Highest_Inns_Score, dtype: int64

# %%
#Question5: Average by country for the following: 100s, 50s & 0s

# %%
df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.375000   8.562500
# ENG      12.692308  21.230769   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.500000  22.000000   6.000000
# PAK      17.600000  23.600000   7.800000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
