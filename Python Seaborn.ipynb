# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
#getting sns dataset names

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
mpg = sns.load_dataset('mpg')

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
#designing of graph

# %%
sns.set_theme()

# %%
sns.set_style('white') #white, dark, whitegrid, darkgrid, ticks

# %%
#setting context (font size, size of chart)

# %%
sns.set_context('paper', font_scale=1.2) #paper, talk, poster

# %%
sns.scatterplot(data=mpg, x='weight', y='mpg')
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
#correlation (only numbers)

# %%
mpg.corr(numeric_only=True)
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
#charting using a heatmap (#https://matplotlib.org/stable/tutorials/colors/colormaps.html)

# %%
sns.heatmap(mpg.corr(numeric_only=True)) #the lighter is the stronger positive correlation, the darker is the stronger negative corr
# Out:
# <Axes: >

# %%
#scatterplot

# %%
sns.scatterplot(data=mpg,x = 'weight', y='mpg')
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
#adding filters through a hue to scatterplot (categorical data)

# %%
sns.scatterplot(data=mpg,x = 'weight', y='mpg',hue = 'origin')
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
 #changing figure size & color palette (https://seaborn.pydata.org/tutorial/color_palettes.html) & despining

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=mpg,x = 'weight', y='mpg',hue = 'origin')
#sns.despine(left=True)
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
#line plot

# %%
sns.lineplot(data=mpg,x = 'model_year', y='mpg')
# Out:
# <Axes: xlabel='model_year', ylabel='mpg'>

# %%
#point plot

# %%
sns.pointplot(data=mpg,x = 'model_year', y='mpg')
# Out:
# <Axes: xlabel='model_year', ylabel='mpg'>

# %%
#KDE Plot

# %%
sns.kdeplot(data=mpg, x='weight', y='mpg') #not plotting correctly
# Out:
# <Axes: xlabel='weight', ylabel='mpg'>

# %%
#histogram

# %%
sns.histplot(data=mpg,x='mpg')
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %%
sns.histplot(data=mpg,x='mpg',kde=True) #able to add bins
# Out:
# <Axes: xlabel='mpg', ylabel='Count'>

# %%
#ECDF Plot

# %%
sns.ecdfplot(data=mpg,x='mpg')
# Out:
# <Axes: xlabel='mpg', ylabel='Proportion'>

# %%
#rug plot

# %%
sns.rugplot(data=mpg, x='mpg')
# Out:
# <Axes: xlabel='mpg'>

# %%
#categorical plots

# %%
sns.countplot(data=mpg, x='origin',hue='origin')
# Out:
# <Axes: xlabel='origin', ylabel='count'>

# %%
#bar plot

# %%
sns.barplot(data=mpg,x='origin',y='mpg',hue='origin')
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
#box plot

# %%
sns.boxplot(data=mpg,x='origin',y='mpg',hue='origin')
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
#violin plot

# %%
sns.violinplot(data=mpg,x='origin',y='mpg',hue='origin')
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
#strip plot (mixing box plot with with scatter plot)

# %%
sns.stripplot(data=mpg,x='origin',y='mpg',hue='origin')
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
#joint plot

# %%
sns.jointplot(data=mpg,x='weight',y='mpg')

# %%
sns.jointplot(data=mpg,x='weight',y='mpg', kind='reg')

# %%
sns.jointplot(data=mpg,x='weight',y='mpg', kind='hex')

# %%
#pair plot (remove all categorical data)

# %%
sns.pairplot(data=mpg)

# %%
sns.pairplot(data=mpg,hue='origin')

# %%
#working with more categorical data

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips, x='total_bill', y='tip', col='sex')

# %%
sns.relplot(data=tips, x='total_bill', y='tip', col='time', hue='sex')

# %%
#facet grid

# %%
FG = sns.FacetGrid(tips,row='day')

# %%
FG = sns.FacetGrid(tips,col='day')

# %%
FG = sns.FacetGrid(tips,col='day',row='sex')

# %%
FG = sns.FacetGrid(tips,col='day',row='sex')
FG.map_dataframe(sns.histplot, x='tip')

# %%
FG = sns.FacetGrid(tips,col='day',row='sex')
FG.map_dataframe(sns.scatterplot, x='tip', y='total_bill')
